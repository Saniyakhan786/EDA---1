# %%
# Import Libraries

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import pandas_profiling as pp
import sweetviz as sv

# %% [markdown]
# # DATA CLEANING STEPS

# %%
# THESE STEPS ARE DONE IN THE PREVIOUS NOTEBOOK

# %%
data1 = pd.read_csv("C:/Users/saniyakhan/Downloads/data_clean.csv")

# %%
data1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data2 = data1.iloc[:,1:]

# %%
data2
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data = data2.copy()

# %%
data
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data['Temp C'] = pd.to_numeric(data['Temp C'],errors = 'coerce')

# %%
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C     float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
data['Month'] = pd.to_numeric(data['Month'],errors = 'coerce')

# %%
data['Wind'] = data['Wind'].astype('int64')

# %%
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind         int64
# Temp C     float64
# Month      float64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
data[data.duplicated()].shape
# Out:
# (1, 9)

# %%
data
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0     7    67.0    5.0    1  2010    67       S
# 1     36.0    118.0     8    72.0    5.0    2  2010    72       C
# 2     12.0    149.0    12    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0    11    62.0    5.0    4  2010    62       S
# 4      NaN      NaN    14    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0     7    67.0    5.0    1  2010    67       C
# 154   30.0    193.0     6    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0    13    77.0    9.0   27  2010    77       S
# 156   14.0    191.0    14    75.0    9.0   28  2010    75       S
# 157   18.0    131.0     8    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data[data.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 156   14.0    191.0    14    75.0    9.0   28  2010    75       S

# %%
data_cleaned1 = data.drop_duplicates()

# %%
data_cleaned1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0     7    67.0    5.0    1  2010    67       S
# 1     36.0    118.0     8    72.0    5.0    2  2010    72       C
# 2     12.0    149.0    12    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0    11    62.0    5.0    4  2010    62       S
# 4      NaN      NaN    14    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 152   20.0    223.0    11    68.0    9.0   30  2010    68       S
# 153   41.0    190.0     7    67.0    5.0    1  2010    67       C
# 154   30.0    193.0     6    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0    13    77.0    9.0   27  2010    77       S
# 157   18.0    131.0     8    76.0    9.0   29  2010    76       C
#
# [157 rows x 9 columns]

# %%
data_cleaned2 = data_cleaned1.drop('Temp C',axis = 1)

# %%
data_cleaned2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0     7    5.0    1  2010    67       S
# 1     36.0    118.0     8    5.0    2  2010    72       C
# 2     12.0    149.0    12    5.0    3  2010    74      PS
# 3     18.0    313.0    11    5.0    4  2010    62       S
# 4      NaN      NaN    14    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0    11    9.0   30  2010    68       S
# 153   41.0    190.0     7    5.0    1  2010    67       C
# 154   30.0    193.0     6    9.0   26  2010    70      PS
# 155    NaN    145.0    13    9.0   27  2010    77       S
# 157   18.0    131.0     8    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned3 = data_cleaned2.rename({'Solar.R': 'Solar'}, axis = 1)

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0     7    5.0    1  2010    67       S
# 1     36.0  118.0     8    5.0    2  2010    72       C
# 2     12.0  149.0    12    5.0    3  2010    74      PS
# 3     18.0  313.0    11    5.0    4  2010    62       S
# 4      NaN    NaN    14    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0    11    9.0   30  2010    68       S
# 153   41.0  190.0     7    5.0    1  2010    67       C
# 154   30.0  193.0     6    9.0   26  2010    70      PS
# 155    NaN  145.0    13    9.0   27  2010    77       S
# 157   18.0  131.0     8    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
# HERE DATA CLEANING STEPS GETS OVER

# %% [markdown]
# # Treat Missing Values and Impute the Missing

# %% [markdown]
# # Heatmap

# %%
cols = data_cleaned3.columns 
colours = ['#000099', '#ffff00']    # here yellow stands for missing and blue stands for non missing values

# %%
sns.heatmap(data_cleaned3[cols].isnull(),
            cmap=sns.color_palette(colours))

# %%
data_cleaned3[data_cleaned3.isnull().any(axis=1)].head()
# Out:
#     Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 4     NaN    NaN    14    5.0    5  2010    56       S
# 5    28.0    NaN    14    5.0    6  2010    66       C
# 9     NaN  194.0     8    5.0   10  2010    69       S
# 10    7.0    NaN     6    5.0   11  2010    74       C
# 23   32.0   92.0    12    NaN   24  2010    61       C

# %%
data_cleaned3.isnull().sum()        # It will show missing values sum
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
# Mean Imputation

# %%
mean = data_cleaned3['Ozone'].mean()
print(mean)
# Out:
# 41.81512605042017

# %%
# Missing value imputation for categorical vlaue

# %%
obj_columns = data_cleaned3[['Weather']]        # Get the object columns

# %%
obj_columns.isnull().sum()                 # Verify
# Out:
# Weather    3
# dtype: int64

# %%
# Missing value imputation for categorical vlaue

# %%
obj_columns = obj_columns.fillna(obj_columns.mode().iloc[0])

# %%
obj_columns.isnull().sum()
# Out:
# Weather    0
# dtype: int64

# %%
data_cleaned3.shape
# Out:
# (157, 8)

# %%
obj_columns.shape
# Out:
# (157, 1)

# %%
data_cleaned4 = data_cleaned3.iloc[:,:7]   # drop the columns with NaN in order to append the imputed weather column to original dataframe

# %%
data_cleaned4.head()       # check if column has been dropped
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temp
# 0   41.0  190.0     7    5.0    1  2010    67
# 1   36.0  118.0     8    5.0    2  2010    72
# 2   12.0  149.0    12    5.0    3  2010    74
# 3   18.0  313.0    11    5.0    4  2010    62
# 4    NaN    NaN    14    5.0    5  2010    56

# %%
data_cleaned4 = pd.concat([data_cleaned4,obj_columns],axis=1)       # join the data set with imputed object dataset

# %%
data_cleaned4.shape
# Out:
# (157, 8)

# %%
data_cleaned4.head()
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0   41.0  190.0     7    5.0    1  2010    67       S
# 1   36.0  118.0     8    5.0    2  2010    72       C
# 2   12.0  149.0    12    5.0    3  2010    74      PS
# 3   18.0  313.0    11    5.0    4  2010    62       S
# 4    NaN    NaN    14    5.0    5  2010    56       S

# %%
data_cleaned4.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     0
# dtype: int64
